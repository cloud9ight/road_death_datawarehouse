# %%
#Import necessary libraries, pandas, numpy and mlxtend
import pandas as pd
import numpy as np
import mlxtend
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %%
# --- Step 1: Load the Excel files ---
crashes = pd.read_excel(
    'bitre_fatal_crashes_dec2024.xlsx', 
    sheet_name='BITRE_Fatal_Crash',
    skiprows=4
)
fatalities = pd.read_excel(
    'bitre_fatalities_dec2024.xlsx', 
    sheet_name='BITRE_Fatality', 
    skiprows=4)

# %%
crashes.head()
# Out:
#    Crash ID State  Month  Year Dayweek      Time Crash Type  \
# 0  20241115   NSW     12  2024  Friday  04:00:00     Single
# 1  20241125   NSW     12  2024  Friday  06:15:00     Single
# 2  20246013   Tas     12  2024  Friday  09:43:00   Multiple
# 3  20241002   NSW     12  2024  Friday  10:35:00   Multiple
# 4  20242261   Vic     12  2024  Friday  11:30:00   Multiple
#
#    Number Fatalities Bus \nInvolvement Heavy Rigid Truck Involvement  \
# 0                  1                No                            No
# 1                  1                No                            No
# 2                  1                No                            No
# 3                  1                No                            No
# 4                  1                -9                            -9
#
#   Articulated Truck Involvement Speed Limit National Remoteness Areas  \
# 0                            No         100  Inner Regional Australia
# 1                            No          80  Inner Regional Australia
# 2                            No          50  Inner Regional Australia
# 3                            No         100  Outer Regional Australia
# 4                            -9          -9                   Unknown
#
#                             SA4 Name 2021 National LGA Name 2021  \
# 0                                Riverina            Wagga Wagga
# 1  Sydney - Baulkham Hills and Hawkesbury             Hawkesbury
# 2               Launceston and North East      Northern Midlands
# 3              New England and North West      Armidale Regional
# 4                                     NaN                    NaN
#
#           National Road Type Christmas Period Easter Period Day of week  \
# 0              Arterial Road              Yes            No     Weekday
# 1                 Local Road               No            No     Weekday
# 2                 Local Road              Yes            No     Weekday
# 3  National or State Highway               No            No     Weekday
# 4               Undetermined               No            No     Weekday
#
#   Time of Day
# 0       Night
# 1         Day
# 2         Day
# 3         Day
# 4         Day

# %%
# --- Step 2: Merge datasets on 'Crash ID' ---
crashes['Crash ID'] = crashes['Crash ID'].astype(str)
fatalities['Crash ID'] = fatalities['Crash ID'].astype(str)

merged_df = pd.merge(fatalities, crashes, on="Crash ID", suffixes=('_fatal', '_crash'))

# %%
merged_df.shape
# Out:
# (56874, 42)

# %%
merged_df.columns
# Out:
# Index(['Crash ID', 'State_fatal', 'Month_fatal', 'Year_fatal', 'Dayweek_fatal',
#        'Time_fatal', 'Crash Type_fatal', 'Bus Involvement',
#        'Heavy Rigid Truck Involvement_fatal',
#        'Articulated Truck Involvement_fatal', 'Speed Limit_fatal', 'Road User',
#        'Gender', 'Age', 'National Remoteness Areas_fatal',
#        'SA4 Name 2021_fatal', 'National LGA Name 2021_fatal',
#        'National Road Type_fatal', 'Christmas Period_fatal',
#        'Easter Period_fatal', 'Age Group', 'Day of week_fatal', 'Time of day',
#        'State_crash', 'Month_crash', 'Year_crash', 'Dayweek_crash',
#        'Time_crash', 'Crash Type_crash', 'Number Fatalities',
#        'Bus \nInvolvement', 'Heavy Rigid Truck Involvement_crash',
#        'Articulated Truck Involvement_crash', 'Speed Limit_crash',
#        'National Remoteness Areas_crash', 'SA4 Name 2021_crash',
#        'National LGA Name 2021_crash', 'National Road Type_crash',
#        'Christmas Period_crash', 'Easter Period_crash', 'Day of week_crash',
#        'Time of Day'],
#       dtype='object')

# %%
# --- Step 2: Data Cleaning ---
# replace -9 with NaN
merged_df.replace(-9, pd.NA, inplace=True)

# Clean the speed limit values
merged_df['Speed Limit_fatal'] = merged_df['Speed Limit_fatal'].replace('<40', '40')

merged_df = merged_df.dropna(subset=['Speed Limit_fatal'])
merged_df['Speed Limit_fatal'] = merged_df['Speed Limit_fatal'].astype(int)

# %%
# --- Step 4: Select columns for association rule mining ---
selected_cols = [
    'Gender', 'Age Group', 'Crash Type_fatal', 'Bus Involvement',
    'Articulated Truck Involvement_fatal', 'Speed Limit_fatal',
     'Christmas Period_fatal',
    'Easter Period_fatal', 
    'Day of week_fatal', 'Time of day', 'Road User'
]

# %%
arm_data = merged_df[selected_cols]

# %%
arm_data.isna().sum()
# Out:
# Gender                                 33
# Age Group                              94
# Crash Type_fatal                        0
# Bus Involvement                        52
# Articulated Truck Involvement_fatal    46
# Speed Limit_fatal                       0
# Christmas Period_fatal                  0
# Easter Period_fatal                     0
# Day of week_fatal                       0
# Time of day                             0
# Road User                               0
# dtype: int64

# %%
#  drop rows with missing values 
arm_data = arm_data.dropna()

arm_data.isna().sum()
# Out:
# Gender                                 0
# Age Group                              0
# Crash Type_fatal                       0
# Bus Involvement                        0
# Articulated Truck Involvement_fatal    0
# Speed Limit_fatal                      0
# Christmas Period_fatal                 0
# Easter Period_fatal                    0
# Day of week_fatal                      0
# Time of day                            0
# Road User                              0
# dtype: int64

# %%
arm_data.dtypes
# Out:
# Gender                                 object
# Age Group                              object
# Crash Type_fatal                       object
# Bus Involvement                        object
# Articulated Truck Involvement_fatal    object
# Speed Limit_fatal                       int64
# Christmas Period_fatal                 object
# Easter Period_fatal                    object
# Day of week_fatal                      object
# Time of day                            object
# Road User                              object
# dtype: object

# %%
# --- Step 5: Discretize Speed Limit into categories ---
arm_data['Speed Bin'] = pd.cut(
    arm_data['Speed Limit_fatal'].astype(float),
    bins=[0, 50, 80, 100, 130, 200],
    labels=['0-50', '51-80', '81-100', '101-130', '131+']
)

# Drop original speed and use Speed Bin instead
arm_data = arm_data.drop(columns=['Speed Limit_fatal'])
arm_data['Speed Bin'] = arm_data['Speed Bin'].astype(str)

# %%
arm_data.head(30)
# Out:
#     Gender Age Group Crash Type_fatal Bus Involvement  \
# 0     Male  65_to_74           Single              No
# 1   Female  17_to_25           Single              No
# 2   Female  26_to_39         Multiple              No
# 3   Female  26_to_39         Multiple              No
# 5   Female  40_to_64         Multiple              No
# 6     Male  40_to_64           Single              No
# 7     Male  65_to_74           Single              No
# 8   Female  26_to_39         Multiple              No
# 9     Male  17_to_25         Multiple              No
# 10  Female  40_to_64         Multiple              No
# 11  Female  40_to_64           Single              No
# 12    Male  40_to_64           Single              No
# 13    Male  40_to_64         Multiple              No
# 14    Male  40_to_64           Single              No
# 17    Male  65_to_74           Single              No
# 19    Male  17_to_25           Single              No
# 20    Male   0_to_16           Single              No
# 21    Male  26_to_39         Multiple              No
# 22    Male  65_to_74         Multiple              No
# 23    Male  26_to_39           Single              No
# 24  Female  26_to_39           Single              No
# 25  Female  65_to_74           Single              No
# 28    Male  26_to_39           Single              No
# 29  Female  40_to_64           Single              No
# 30  Female  40_to_64           Single              No
# 32    Male  26_to_39         Multiple             Yes
# 33    Male  17_to_25           Single              No
# 35    Male  17_to_25           Single              No
# 36    Male  26_to_39           Single              No
# 37    Male  65_to_74         Multiple              No
#
#    Articulated Truck Involvement_fatal Christmas Period_fatal  \
# 0                                   No                    Yes
# 1                                   No                     No
# 2                                   No                    Yes
# 3                                   No                     No
# 5                                   No                     No
# 6                                   No                    Yes
# 7                                   No                     No
# 8                                   No                     No
# 9                                   No                     No
# 10                                  No                     No
# 11                                  No                     No
# 12                                  No                     No
# 13                                 Yes                     No
# 14                                  No                     No
# 17                                  No                     No
# 19                                 Yes                     No
# 20                                  No                    Yes
# 21                                  No                     No
# 22                                  No                    Yes
# 23                                  No                     No
# 24                                  No                    Yes
# 25                                  No                     No
# 28                                  No                    Yes
# 29                                  No                    Yes
# 30                                  No                    Yes
# 32                                 Yes                     No
# 33                                  No                     No
# 35                                  No                     No
# 36                                  No                     No
# 37                                  No                     No
#
#    Easter Period_fatal Day of week_fatal Time of day         Road User  \
# 0                   No           Weekday       Night            Driver
# 1                   No           Weekday         Day            Driver
# 2                   No           Weekday         Day            Driver
# 3                   No           Weekday         Day            Driver
# 5                   No           Weekday         Day         Passenger
# 6                   No           Weekday         Day  Motorcycle rider
# 7                   No           Weekday         Day            Driver
# 8                   No           Weekend       Night         Passenger
# 9                   No           Weekend       Night  Motorcycle rider
# 10                  No           Weekend       Night            Driver
# 11                  No           Weekend       Night            Driver
# 12                  No           Weekend       Night        Pedestrian
# 13                  No           Weekend       Night            Driver
# 14                  No           Weekend       Night            Driver
# 17                  No           Weekday         Day        Pedestrian
# 19                  No           Weekday         Day            Driver
# 20                  No           Weekday         Day        Pedestrian
# 21                  No           Weekday         Day            Driver
# 22                  No           Weekday         Day            Driver
# 23                  No           Weekday         Day            Driver
# 24                  No           Weekday         Day            Driver
# 25                  No           Weekday         Day        Pedestrian
# 28                  No           Weekday       Night        Pedestrian
# 29                  No           Weekday       Night            Driver
# 30                  No           Weekday       Night            Driver
# 32                  No           Weekend       Night            Driver
# 33                  No           Weekend       Night            Driver
# 35                  No           Weekend       Night         Passenger
# 36                  No           Weekend         Day            Driver
# 37                  No           Weekend         Day  Motorcycle rider
#
#    Speed Bin
# 0     81-100
# 1      51-80
# 2       0-50
# 3     81-100
# 5     81-100
# 6     81-100
# 7     81-100
# 8      51-80
# 9       0-50
# 10    81-100
# 11      0-50
# 12     51-80
# 13   101-130
# 14    81-100
# 17     51-80
# 19     51-80
# 20     51-80
# 21    81-100
# 22    81-100
# 23    81-100
# 24   101-130
# 25      0-50
# 28     51-80
# 29   101-130
# 30   101-130
# 32   101-130
# 33    81-100
# 35     51-80
# 36     51-80
# 37    81-100

# %%
# --- Step 6: Convert each row into a transaction of "attribute=value" ---
transactions = []
for _, row in arm_data.iterrows():
    transaction = [f"{col}={row[col]}" for col in arm_data.columns]
    transactions.append(transaction)

# %%
# --- Step 7: Encode transactions using TransactionEncoder ---
te = TransactionEncoder()
te_array = te.fit(transactions).transform(transactions)
arm_df = pd.DataFrame(te_array, columns=te.columns_)

# %%
# --- Step 8: Run Apriori algorithm ---
frequent_itemsets = apriori(arm_df, min_support=0.05, use_colnames=True)

# %%
# --- Step 9: Generate association rules ---
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.5)

# %%
# --- Step 10: Filter rules with "Road User" on the RHS (consequent) ---
rules_with_road_user = rules[rules['consequents'].apply(lambda x: any('Road User=' in str(i) for i in x))]

# %%
# Sort by lift and confidence
top_rules = rules_with_road_user.sort_values(by=['lift', 'confidence'], ascending=False)

# %%
# --- Step 11: Display top k rules ---
k = 5
top_k_rules = top_rules.head(k)[['antecedents', 'consequents', 'support', 'confidence', 'lift']]
print("\nTop Rules with 'Road User' on RHS:\n")
print(top_k_rules.to_string(index=False))
# Out:
# Top Rules with 'Road User' on RHS:
#
#                                                                    antecedents                                                                               consequents  support  confidence     lift
#                  (Articulated Truck Involvement_fatal=Yes, Bus Involvement=No)                                             (Crash Type_fatal=Multiple, Road User=Driver) 0.050128    0.503090 2.321781
#              (Articulated Truck Involvement_fatal=Yes, Easter Period_fatal=No)                                             (Crash Type_fatal=Multiple, Road User=Driver) 0.050363    0.500991 2.312095
#                                      (Articulated Truck Involvement_fatal=Yes)                                             (Crash Type_fatal=Multiple, Road User=Driver) 0.050508    0.500898 2.311666
#                         (Articulated Truck Involvement_fatal=Yes, Gender=Male) (Road User=Driver, Bus Involvement=No, Christmas Period_fatal=No, Easter Period_fatal=No) 0.050037    0.663067 1.529530
# (Articulated Truck Involvement_fatal=Yes, Gender=Male, Easter Period_fatal=No)                         (Bus Involvement=No, Christmas Period_fatal=No, Road User=Driver) 0.050037    0.665623 1.527386
