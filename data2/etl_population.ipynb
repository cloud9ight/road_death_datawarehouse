# %%
# Import Library
import pandas as pd
import numpy as np

# %%
population_df = pd.read_excel(
    'Population estimates by LGA, Significant Urban Area, Remoteness Area, Commonwealth Electoral Division and State Electoral Division, 2001 to 2023.xlsx', 
    sheet_name='Table 3',
    skiprows=6
)
print(population_df.head(10))
# Out:
#    State/Territory                   Remoteness Area        no.      no..1  \
# 0  New South Wales   Major Cities of Australia (NSW)  4791646.0  4832878.0
# 1              NaN    Inner Regional Australia (NSW)  1309389.0  1321149.0
# 2              NaN    Outer Regional Australia (NSW)   384554.0   382991.0
# 3              NaN            Remote Australia (NSW)    34756.0    34075.0
# 4              NaN       Very Remote Australia (NSW)    10004.0     9714.0
# 5              NaN             Total New South Wales  6530349.0  6580807.0
# 6         Victoria  Major Cities of Australia (Vic.)  3568891.0  3615482.0
# 7              NaN   Inner Regional Australia (Vic.)   951267.0   958509.0
# 8              NaN   Outer Regional Australia (Vic.)   239267.0   239670.0
# 9              NaN           Remote Australia (Vic.)     4190.0     4113.0
#
#        no..2      no..3      no..4      no..5      no..6      no..7  ...  \
# ...

# %%
population_excel_file = 'Population estimates by LGA, Significant Urban Area, Remoteness Area, Commonwealth Electoral Division and State Electoral Division, 2001 to 2023.xlsx'
population_sheet_name = 'Table 3' # This sheet focuses on Remoteness Areas
rows_to_skip = 6 # Skip the title, notes, etc., to get to the header rows
output_population_csv = 'fact_population_remoteness.csv'

# %%
# Out:
# Reading data from:
# File: Population estimates by LGA, Significant Urban Area, Remoteness Area, Commonwealth Electoral Division and State Electoral Division, 2001 to 2023.xlsx
# Sheet: Table 3
# Skipping 6 rows...
#
# --- Initial Data Read (first 5 rows) ---
#   State/Territory                 Remoteness Area        no.             \
#   New South Wales Major Cities of Australia (NSW)    4791646    4832878
# 0             NaN  Inner Regional Australia (NSW)  1309389.0  1321149.0
# 1             NaN  Outer Regional Australia (NSW)   384554.0   382991.0
# 2             NaN          Remote Australia (NSW)    34756.0    34075.0
# 3             NaN     Very Remote Australia (NSW)    10004.0     9714.0
# 4             NaN           Total New South Wales  6530349.0  6580807.0
#
#                                                                      ...  \
#      4867228    4894766    4931770    4974013    5052320    5146661  ...
# ...

# %%
# Out:
# Renaming '('State/Territory', 'New South Wales')' to 'State_Territory'
# Renaming '('Remoteness Area', 'Major Cities of Australia (NSW)')' to 'Remoteness_Area'
# Flattening multi-index columns...
#
# --- Columns after renaming and flattening ---
# Index(['State/Territory_New South Wales',
#        'Remoteness Area_Major Cities of Australia (NSW)', 'no._4791646',
#        'no._4832878', 'no._4867228', 'no._4894766', 'no._4931770',
#        'no._4974013', 'no._5052320', 'no._5146661', 'no._5239193',
#        'no._5311924', 'no._5373687', 'no._5448022', 'no._5535597',
#        'no._5627414', 'no._5723253', 'no._5825821', 'no._5930874',
#        'no._6011991', 'no._6088337', 'no._6137535', 'no._6112572',
#        'no._6166301', 'no._6324725'],
#       dtype='object')
#
# --- Data Head after renaming ---
#   State/Territory_New South Wales  \
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# ...
